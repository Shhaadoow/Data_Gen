# %% [markdown]
# ANALISIS DEL TRASTORNO PTSD

# %%
import polars as pl
from pathlib import Path

# =========================================
# CONFIGURACIÓN VISUAL
# =========================================

pl.Config.set_tbl_cols(-1)
pl.Config.set_tbl_rows(10)
pl.Config.set_tbl_width_chars(300)
pl.Config.set_fmt_str_lengths(100)

# =========================================
# RUTA DATA/PTSD
# =========================================

ruta = Path(
    r"C:\Users\ASUS\.cache\huggingface\hub\datasets--lighteternal--pgc-psychiatric-gwas-harmonized\snapshots\6c3241136562df51a4e942d84a466a4202866c99\data\ptsd.parquet"
)

# =========================================
# LECTURA
# =========================================

df = pl.read_parquet(ruta)

# =========================================
# MOSTRAR FxC
# =========================================

print("=" * 100)
print("PTSD.PARQUET - DATA")
print("=" * 100)

print(f"\nFilas x Columnas: {df.shape}")

# =========================================
# MOSTRAR 10 FILAS Y 31 COLUMNAS
# =========================================

print("\nPRIMERAS 10 FILAS\n")

print(df.head(10))
# Out:
# ...
# PTSD.PARQUET - DATA
# ...
#
# Filas x Columnas: (19000015, 31)
#
# PRIMERAS 10 FILAS
#
# shape: (10, 31)
# ┌──────────┬──────────┬─────────┬─────────┬─────┬─────────┬─────────┬─────────┬──────┬───────┬─────────┬─────────┬────────┬─────────┬─────────┬─────────┬──────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┐
# │ variant_ ┆ variant_ ┆ snp_id  ┆ raw_snp ┆ chr ┆ pos     ┆ effect_ ┆ other_a ┆ a1   ┆ a2    ┆ effect_ ┆ effect_ ┆ se     ┆ se_sour ┆ pval    ┆ sig_tie ┆ maf  ┆ info    ┆ disorde ┆ source_ ┆ source_ ┆ source_ ┆ role    ┆ source_ ┆ was_fli ┆ is_pali ┆ is_bial ┆ usable_ ┆ referen ┆ alignme ┆ tested_ │
# ...
